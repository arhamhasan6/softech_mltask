# %%
# !pip install ultralytics
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.9/618.9 kB 10.5 MB/s eta 0:00:00
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu117
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

# Load a model

model = YOLO('yolov8n.yaml').load('yolov8n.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# %cd /content/drive/MyDrive/archive

# !yolo task=detect mode=train model=/content/yolov8n.pt data= data.yaml epochs=2 imgsz=1024 plots=True batch=32
# Out:
# /content/drive/MyDrive/archive
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/test/images

# !yolo task=detect mode=predict model=/content/drive/MyDrive/archive/runs/detect/train6/weights/best.pt source=/content/drive/MyDrive/archive/v1.mp4 show=True
# Out:
# /content/drive/MyDrive/test/images
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/933) /content/drive/MyDrive/archive/v1.mp4: 576x1024 (no detections), 168.2ms
# video 1/1 (2/933) /content/drive/MyDrive/archive/v1.mp4: 576x1024 (no detections), 8.6ms
# video 1/1 (3/933) /content/drive/MyDrive/archive/v1.mp4: 576x1024 (no detections), 8.6ms
# video 1/1 (4/933) /content/drive/MyDrive/archive/v1.mp4: 576x1024 (no detections), 8.6ms
# video 1/1 (5/933) /content/drive/MyDrive/archive/v1.mp4: 576x1024 (no detections), 8.6ms
# video 1/1 (6/933) /content/drive/MyDrive/archive/v1.mp4: 576x1024 (no detections), 8.8ms
# video 1/1 (7/933) /content/drive/MyDrive/archive/v1.mp4: 576x1024 (no detections), 8.6ms
# ...
